# %%
import numpy as np
import pandas as pd 
import string
import nltk
from nltk.corpus import stopwords
import re
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# %%
df = pd.read_excel("/Users/ateekshachaudhary/Downloads/NewTask2.xlsx", header=0,index_col=None)
df.shape
# Out:
# (9960, 6)

# %%
df['News_Headline']= df['News_Headline'].str.lower()
df['News_Headline']
# Out:
# 0                 says osama bin laden endorsed joe biden
# 1       cnn aired a video of a toddler running away fr...
# 2       says tim tebow ìkneeled in protest of abortion...
# 3       ìeven so-called moderate democrats like joe bi...
# 4       "our health department, our city and our count...
#                               ...
# 9955    says the obama administration plans to reduce ...
# 9956    the foreign intelligence surveillance court "i...
# 9957    "in the past four years, (the u.s. senate) has...
# 9958    on immigration reform, marco rubio "all along ...
# 9959    "since newtown, more people have died at the e...
# Name: News_Headline, Length: 9960, dtype: object

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ateekshachaudhary/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ateekshachaudhary/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stopwords = set(stopwords.words('english'))

# %%
df['News_Headline']=df['News_Headline'].apply(str)

# %%
df['News_Headline']
# Out:
# 0                 says osama bin laden endorsed joe biden
# 1       cnn aired a video of a toddler running away fr...
# 2       says tim tebow ìkneeled in protest of abortion...
# 3       ìeven so-called moderate democrats like joe bi...
# 4       "our health department, our city and our count...
#                               ...
# 9955    says the obama administration plans to reduce ...
# 9956    the foreign intelligence surveillance court "i...
# 9957    "in the past four years, (the u.s. senate) has...
# 9958    on immigration reform, marco rubio "all along ...
# 9959    "since newtown, more people have died at the e...
# Name: News_Headline, Length: 9960, dtype: object

# %%
df['cleaned'] = df['News_Headline'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
df['cleaned']
# Out:
# 0                 says osama bin laden endorsed joe biden
# 1       cnn aired video toddler running away another t...
# 2       says tim tebow ìkneeled protest abortion natio...
# 3       ìeven so-called moderate democrats like joe bi...
# 4       "our health department, city county declared r...
#                               ...
# 9955    says obama administration plans reduce number ...
# 9956    foreign intelligence surveillance court "is tr...
# 9957    "in past four years, (the u.s. senate) passed ...
# 9958    immigration reform, marco rubio "all along say...
# 9959    "since newtown, people died end gun lost afgha...
# Name: cleaned, Length: 9960, dtype: object

# %%
i=0
data = []
for s in df['cleaned']:
    word = s.split()
    cleaned = ' '.join(i for i in word if i not in stopwords and i not in string.punctuation)
    cleaned = [re.sub(r'[^\w\s]', '', cleaned)]
    data.append(cleaned)
    
    #print(cleaned)
df['CleanedNews'] = pd.DataFrame(data)
df['CleanedNews'] = df['CleanedNews'].str.replace('\d+', '')
df['CleanedNews'] = df.CleanedNew.replace('<br/>','', regex=True)
df
# Out:
# <ipython-input-48-161642c16793>:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['CleanedNews'] = df['CleanedNews'].str.replace('\d+', '')
#                                           News_Headline  \
# 0               says osama bin laden endorsed joe biden
# 1     cnn aired a video of a toddler running away fr...
# 2     says tim tebow ìkneeled in protest of abortion...
# 3     ìeven so-called moderate democrats like joe bi...
# 4     "our health department, our city and our count...
# ...                                                 ...
# 9955  says the obama administration plans to reduce ...
# 9956  the foreign intelligence surveillance court "i...
# 9957  "in the past four years, (the u.s. senate) has...
# 9958  on immigration reform, marco rubio "all along ...
# 9959  "since newtown, more people have died at the e...
#
#                                            Link_Of_News            Source  \
# ...

# %%
df1=df.dropna()
df1.shape
# Out:
# (9960, 8)

# %%
df1= df.drop(['CleanedNew', 'cleaned'], axis= 1)
df1
# Out:
#                                           News_Headline  \
# 0               says osama bin laden endorsed joe biden
# 1     cnn aired a video of a toddler running away fr...
# 2     says tim tebow ìkneeled in protest of abortion...
# 3     ìeven so-called moderate democrats like joe bi...
# 4     "our health department, our city and our count...
# ...                                                 ...
# 9955  says the obama administration plans to reduce ...
# 9956  the foreign intelligence surveillance court "i...
# 9957  "in the past four years, (the u.s. senate) has...
# 9958  on immigration reform, marco rubio "all along ...
# 9959  "since newtown, more people have died at the e...
#
#                                            Link_Of_News            Source  \
# 0     https://www.politifact.com/factchecks/2020/jun...  Donald Trump Jr.
# 1     https://www.politifact.com/factchecks/2020/jun...      Donald Trump
# ...
